# %%
import astropy
print astropy.__version__
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 1.1.1

# %%
from JLA import PhotometryData

# %%
fname = '/Users/rbiswas/Downloads/jla_light_curves/lc-03D1au.list'

# %%
s = PhotometryData(fname)

# %%
s.photometryTable.dtype
# Out:
# dtype([('time', '<f8'), ('flux', '<f8'), ('fluxerr', '<f8'), ('zp', '<f8'), ('band', 'S13'), ('zpsys', 'S6')])

# %%
import sncosmo

# %%
# Don't do the following, use the megacam bands and set prefix to something like SNLS

# %%
s.band_prefix = 'des'

# %%
s.photometryTable
# Out:
# <Table length=69>
#   time       flux        fluxerr         zp     band zpsys
# float64    float64       float64      float64  str13  str6
# -------- ------------ -------------- --------- ----- -----
# 52880.58  -0.27222547 0.576573496621 27.068905  desg    ab
# 52900.49    24.912944  1.44586038479 27.068905  desg    ab
#  52904.6    27.736347 0.835438640671 27.068905  desg    ab
# 52908.53    27.231098 0.787584678294 27.068905  desg    ab
# 52930.39    6.8619872 0.704436477531 27.068905  desg    ab
# 52934.53    4.9811785 0.636380445201 27.068905  desg    ab
# 52937.55    4.4990491  1.08032942991 27.068905  desg    ab
# 52944.39    2.1356459  1.22674137546 27.068905  desg    ab
# 52961.45    2.3272014  1.15645044124 27.068905  desg    ab
# 52964.37      1.17315 0.763536581685 27.068905  desg    ab
#      ...          ...            ...       ...   ...   ...
# 52881.56   0.10938977  0.68327798891  25.37553  desz    ab
# 52900.59    10.457789 0.954111893571  25.37553  desz    ab
# 52909.61    13.961113 0.914066867433  25.37553  desz    ab
# 52930.41    8.1003033 0.985067241909  25.37553  desz    ab
# 52938.51    6.4052915  1.06888630337  25.37553  desz    ab
# 52944.46    6.0349633 0.798367142411  25.37553  desz    ab
# 52962.31    4.0362936 0.649801442616  25.37553  desz    ab
# 52964.44 0.0052527571  1.60439950021  25.37553  desz    ab
# 52999.36   0.49386952  1.27392399327  25.37553  desz    ab
# 53000.24    1.3041272 0.645861617096  25.37553  desz    ab

# %%
sncosmo.plot_lc(s.photometryTable)
